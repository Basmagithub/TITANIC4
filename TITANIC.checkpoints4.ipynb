# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score
B=pd.read_csv("C:/Users/TERIAK-JB/Desktop/GOMYCODE/titanic.csv",encoding ="iso-8859-1")

B.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5     1.0       1.0                              Anderson, Mr. Harry    male
# 6     1.0       1.0                Andrews, Miss. Kornelia Theodosia  female
# 7     1.0       0.0                           Andrews, Mr. Thomas Jr    male
# 8     1.0       1.0    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9     1.0       0.0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0     24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0    113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0    113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0    113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0    113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0000    0.0    0.0     19952   26.5500      E12        S    3    NaN
# 6  63.0000    1.0    0.0     13502   77.9583       D7        S   10    NaN
# 7  39.0000    0.0    0.0    112050    0.0000      A36        S  NaN    NaN
# 8  53.0000    2.0    0.0     11769   51.4792     C101        S    D    NaN
# 9  71.0000    0.0    0.0  PC 17609   49.5042      NaN        C  NaN   22.0
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
# 5                     New York, NY
# 6                       Hudson, NY
# 7                      Belfast, NI
# 8              Bayside, Queens, NY
# 9              Montevideo, Uruguay

# %%
B.tail(13)
# Out:
#       pclass  survived                                     name     sex   age  \
# 1297     3.0       0.0                   Wiseman, Mr. Phillippe    male   NaN
# 1298     3.0       0.0                Wittevrongel, Mr. Camille    male  36.0
# 1299     3.0       0.0                      Yasbeck, Mr. Antoni    male  27.0
# 1300     3.0       1.0  Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1301     3.0       0.0                     Youseff, Mr. Gerious    male  45.5
# 1302     3.0       0.0                        Yousif, Mr. Wazli    male   NaN
# 1303     3.0       0.0                    Yousseff, Mr. Gerious    male   NaN
# 1304     3.0       0.0                     Zabour, Miss. Hileni  female  14.5
# 1305     3.0       0.0                    Zabour, Miss. Thamine  female   NaN
# 1306     3.0       0.0                Zakarian, Mr. Mapriededer    male  26.5
# 1307     3.0       0.0                      Zakarian, Mr. Ortin    male  27.0
# 1308     3.0       0.0                       Zimmerman, Mr. Leo    male  29.0
# 1309     NaN       NaN                                      NaN     NaN   NaN
#
#       sibsp  parch      ticket     fare cabin embarked boat   body home.dest
# 1297    0.0    0.0  A/4. 34244   7.2500   NaN        S  NaN    NaN       NaN
# 1298    0.0    0.0      345771   9.5000   NaN        S  NaN    NaN       NaN
# 1299    1.0    0.0        2659  14.4542   NaN        C    C    NaN       NaN
# 1300    1.0    0.0        2659  14.4542   NaN        C  NaN    NaN       NaN
# 1301    0.0    0.0        2628   7.2250   NaN        C  NaN  312.0       NaN
# 1302    0.0    0.0        2647   7.2250   NaN        C  NaN    NaN       NaN
# 1303    0.0    0.0        2627  14.4583   NaN        C  NaN    NaN       NaN
# 1304    1.0    0.0        2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    1.0    0.0        2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    0.0    0.0        2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    0.0    0.0        2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308    0.0    0.0      315082   7.8750   NaN        S  NaN    NaN       NaN
# 1309    NaN    NaN         NaN      NaN   NaN      NaN  NaN    NaN       NaN

# %%
B.dropna(axis=0,how='all',inplace=True)

# %%
B
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304     3.0       0.0                             Zabour, Miss. Hileni
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000    0.0    0.0   24160  211.3375       B5        S    2
# 1       male   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11
# 2     female   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000    1.0    0.0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN    1.0    0.0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000    0.0    0.0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000    0.0    0.0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000    0.0    0.0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
B.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
B["age"].fillna(B["age"].mean(),inplace=True)
B["age"]=B["age"].apply(np.int)
B
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304     3.0       0.0                             Zabour, Miss. Hileni
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female   29    0.0    0.0   24160  211.3375       B5        S    2
# 1       male    0    1.0    2.0  113781  151.5500  C22 C26        S   11
# 2     female    2    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 3       male   30    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 4     female   25    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# ...      ...  ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female   14    1.0    0.0    2665   14.4542      NaN        C  NaN
# 1305  female   29    1.0    0.0    2665   14.4542      NaN        C  NaN
# 1306    male   26    0.0    0.0    2656    7.2250      NaN        C  NaN
# 1307    male   27    0.0    0.0    2670    7.2250      NaN        C  NaN
# 1308    male   29    0.0    0.0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
B["survived"]=B["survived"].apply(np.int)
B
# Out:
#       pclass  survived                                             name  \
# 0        1.0         1                    Allen, Miss. Elisabeth Walton
# 1        1.0         1                   Allison, Master. Hudson Trevor
# 2        1.0         0                     Allison, Miss. Helen Loraine
# 3        1.0         0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304     3.0         0                             Zabour, Miss. Hileni
# 1305     3.0         0                            Zabour, Miss. Thamine
# 1306     3.0         0                        Zakarian, Mr. Mapriededer
# 1307     3.0         0                              Zakarian, Mr. Ortin
# 1308     3.0         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female   29    0.0    0.0   24160  211.3375       B5        S    2
# 1       male    0    1.0    2.0  113781  151.5500  C22 C26        S   11
# 2     female    2    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 3       male   30    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 4     female   25    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# ...      ...  ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female   14    1.0    0.0    2665   14.4542      NaN        C  NaN
# 1305  female   29    1.0    0.0    2665   14.4542      NaN        C  NaN
# 1306    male   26    0.0    0.0    2656    7.2250      NaN        C  NaN
# 1307    male   27    0.0    0.0    2670    7.2250      NaN        C  NaN
# 1308    male   29    0.0    0.0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
B["pclass"]=B["pclass"].apply(np.int)
B
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female   29    0.0    0.0   24160  211.3375       B5        S    2
# 1       male    0    1.0    2.0  113781  151.5500  C22 C26        S   11
# 2     female    2    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 3       male   30    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 4     female   25    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# ...      ...  ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female   14    1.0    0.0    2665   14.4542      NaN        C  NaN
# 1305  female   29    1.0    0.0    2665   14.4542      NaN        C  NaN
# 1306    male   26    0.0    0.0    2656    7.2250      NaN        C  NaN
# 1307    male   27    0.0    0.0    2670    7.2250      NaN        C  NaN
# 1308    male   29    0.0    0.0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
B["sibsp"]=B["sibsp"].apply(np.int)
B
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female   29      0    0.0   24160  211.3375       B5        S    2
# 1       male    0      1    2.0  113781  151.5500  C22 C26        S   11
# 2     female    2      1    2.0  113781  151.5500  C22 C26        S  NaN
# 3       male   30      1    2.0  113781  151.5500  C22 C26        S  NaN
# 4     female   25      1    2.0  113781  151.5500  C22 C26        S  NaN
# ...      ...  ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female   14      1    0.0    2665   14.4542      NaN        C  NaN
# 1305  female   29      1    0.0    2665   14.4542      NaN        C  NaN
# 1306    male   26      0    0.0    2656    7.2250      NaN        C  NaN
# 1307    male   27      0    0.0    2670    7.2250      NaN        C  NaN
# 1308    male   29      0    0.0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
B["parch"]=B["parch"].apply(np.int)
B
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female   29      0      0   24160  211.3375       B5        S    2
# 1       male    0      1      2  113781  151.5500  C22 C26        S   11
# 2     female    2      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male   30      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female   25      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...  ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female   14      1      0    2665   14.4542      NaN        C  NaN
# 1305  female   29      1      0    2665   14.4542      NaN        C  NaN
# 1306    male   26      0      0    2656    7.2250      NaN        C  NaN
# 1307    male   27      0      0    2670    7.2250      NaN        C  NaN
# 1308    male   29      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
B
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female   29      0      0   24160  211.3375       B5        S    2
# 1       male    0      1      2  113781  151.5500  C22 C26        S   11
# 2     female    2      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male   30      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female   25      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...  ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female   14      1      0    2665   14.4542      NaN        C  NaN
# 1305  female   29      1      0    2665   14.4542      NaN        C  NaN
# 1306    male   26      0      0    2656    7.2250      NaN        C  NaN
# 1307    male   27      0      0    2670    7.2250      NaN        C  NaN
# 1308    male   29      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
B.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age             0
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   int64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 153.4+ KB

# %%
B["fare"].fillna(B["fare"].mode(),inplace=True)
B
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female   29      0      0   24160  211.3375       B5        S    2
# 1       male    0      1      2  113781  151.5500  C22 C26        S   11
# 2     female    2      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male   30      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female   25      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...  ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female   14      1      0    2665   14.4542      NaN        C  NaN
# 1305  female   29      1      0    2665   14.4542      NaN        C  NaN
# 1306    male   26      0      0    2656    7.2250      NaN        C  NaN
# 1307    male   27      0      0    2670    7.2250      NaN        C  NaN
# 1308    male   29      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
B.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age             0
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   int64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 153.4+ KB

# %%
B
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female   29      0      0   24160  211.3375       B5        S    2
# 1       male    0      1      2  113781  151.5500  C22 C26        S   11
# 2     female    2      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male   30      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female   25      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...  ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female   14      1      0    2665   14.4542      NaN        C  NaN
# 1305  female   29      1      0    2665   14.4542      NaN        C  NaN
# 1306    male   26      0      0    2656    7.2250      NaN        C  NaN
# 1307    male   27      0      0    2670    7.2250      NaN        C  NaN
# 1308    male   29      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
B['embarked'].value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: embarked, dtype: int64

# %%
B["embarked"].fillna('S',inplace=True)
B
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female   29      0      0   24160  211.3375       B5        S    2
# 1       male    0      1      2  113781  151.5500  C22 C26        S   11
# 2     female    2      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male   30      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female   25      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...  ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female   14      1      0    2665   14.4542      NaN        C  NaN
# 1305  female   29      1      0    2665   14.4542      NaN        C  NaN
# 1306    male   26      0      0    2656    7.2250      NaN        C  NaN
# 1307    male   27      0      0    2670    7.2250      NaN        C  NaN
# 1308    male   29      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
B["fare"].fillna(B["fare"].median(),inplace=True)
B
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female   29      0      0   24160  211.3375       B5        S    2
# 1       male    0      1      2  113781  151.5500  C22 C26        S   11
# 2     female    2      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male   30      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female   25      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...  ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female   14      1      0    2665   14.4542      NaN        C  NaN
# 1305  female   29      1      0    2665   14.4542      NaN        C  NaN
# 1306    male   26      0      0    2656    7.2250      NaN        C  NaN
# 1307    male   27      0      0    2670    7.2250      NaN        C  NaN
# 1308    male   29      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
B.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age             0
# sibsp           0
# parch           0
# ticket          0
# fare            0
# cabin        1014
# embarked        0
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
B['home.dest'].value_counts()
# Out:
# New York, NY                        64
# London                              14
# Montreal, PQ                        10
# Cornwall / Akron, OH                 9
# Paris, France                        9
#                                     ..
# England New York, NY                 1
# Sweden / Arlington, NJ               1
# North Evington, England              1
# Guernsey, England / Edgewood, RI     1
# Russia                               1
# Name: home.dest, Length: 369, dtype: int64

# %%
B["home.dest"].fillna("New York NK",inplace=True)
B
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female   29      0      0   24160  211.3375       B5        S    2
# 1       male    0      1      2  113781  151.5500  C22 C26        S   11
# 2     female    2      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male   30      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female   25      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...  ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female   14      1      0    2665   14.4542      NaN        C  NaN
# 1305  female   29      1      0    2665   14.4542      NaN        C  NaN
# 1306    male   26      0      0    2656    7.2250      NaN        C  NaN
# 1307    male   27      0      0    2670    7.2250      NaN        C  NaN
# 1308    male   29      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                      New York NK
# 1305    NaN                      New York NK
# 1306  304.0                      New York NK
# 1307    NaN                      New York NK
# 1308    NaN                      New York NK
#
# [1309 rows x 14 columns]

# %%
B.drop("cabin",1,inplace=True)

# %%
B.drop("boat",1,inplace=True)

# %%
B.drop("body",1,inplace=True)

# %%
B
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare embarked  \
# 0     female   29      0      0   24160  211.3375        S
# 1       male    0      1      2  113781  151.5500        S
# 2     female    2      1      2  113781  151.5500        S
# 3       male   30      1      2  113781  151.5500        S
# 4     female   25      1      2  113781  151.5500        S
# ...      ...  ...    ...    ...     ...       ...      ...
# 1304  female   14      1      0    2665   14.4542        C
# 1305  female   29      1      0    2665   14.4542        C
# 1306    male   26      0      0    2656    7.2250        C
# 1307    male   27      0      0    2670    7.2250        C
# 1308    male   29      0      0  315082    7.8750        S
#
#                             home.dest
# 0                        St Louis, MO
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# ...                               ...
# 1304                      New York NK
# 1305                      New York NK
# 1306                      New York NK
# 1307                      New York NK
# 1308                      New York NK
#
# [1309 rows x 11 columns]

# %% [markdown]
# ### relation entre age et sex

# %%
B.pivot_table('survived', index='age',columns='sex',aggfunc="sum").plot()

# %%
B.corr()['survived'].sort_values()
# Out:
# pclass     -0.312469
# age        -0.047021
# sibsp      -0.027825
# parch       0.082660
# fare        0.244414
# survived    1.000000
# Name: survived, dtype: float64

# %%
B
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare embarked  \
# 0     female   29      0      0   24160  211.3375        S
# 1       male    0      1      2  113781  151.5500        S
# 2     female    2      1      2  113781  151.5500        S
# 3       male   30      1      2  113781  151.5500        S
# 4     female   25      1      2  113781  151.5500        S
# ...      ...  ...    ...    ...     ...       ...      ...
# 1304  female   14      1      0    2665   14.4542        C
# 1305  female   29      1      0    2665   14.4542        C
# 1306    male   26      0      0    2656    7.2250        C
# 1307    male   27      0      0    2670    7.2250        C
# 1308    male   29      0      0  315082    7.8750        S
#
#                             home.dest
# 0                        St Louis, MO
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# ...                               ...
# 1304                      New York NK
# 1305                      New York NK
# 1306                      New York NK
# 1307                      New York NK
# 1308                      New York NK
#
# [1309 rows x 11 columns]

# %%
import seaborn as sns 
import pandas as pd
age_survived=pd.crosstab(B['age'],B['survived'])
sns.heatmap (age_survived, annot = True)
age_survived.plot()

# %%
B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   int64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   float64
#  9   embarked   1309 non-null   object
#  10  home.dest  1309 non-null   object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 122.7+ KB

# %%
B.isnull().sum()
# Out:
# pclass       0
# survived     0
# name         0
# sex          0
# age          0
# sibsp        0
# parch        0
# ticket       0
# fare         0
# embarked     0
# home.dest    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

plot_correlation_map( B )

# %%
B[['survived','pclass']].groupby(['pclass'],as_index=True).mean().plot

# %%
# création de colonne TITRE

# %%
C=[]
df=" "
for x in B["name"]:
    df=x.split(",")
    df=df[1].split(".")
    df1=df[0].strip()
    C.append(df1)
    
B["Title"]=C
B
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare embarked  \
# 0     female   29      0      0   24160  211.3375        S
# 1       male    0      1      2  113781  151.5500        S
# 2     female    2      1      2  113781  151.5500        S
# 3       male   30      1      2  113781  151.5500        S
# 4     female   25      1      2  113781  151.5500        S
# ...      ...  ...    ...    ...     ...       ...      ...
# 1304  female   14      1      0    2665   14.4542        C
# 1305  female   29      1      0    2665   14.4542        C
# 1306    male   26      0      0    2656    7.2250        C
# 1307    male   27      0      0    2670    7.2250        C
# 1308    male   29      0      0  315082    7.8750        S
#
#                             home.dest   Title
# 0                        St Louis, MO    Miss
# 1     Montreal, PQ / Chesterville, ON  Master
# 2     Montreal, PQ / Chesterville, ON    Miss
# 3     Montreal, PQ / Chesterville, ON      Mr
# 4     Montreal, PQ / Chesterville, ON     Mrs
# ...                               ...     ...
# 1304                      New York NK    Miss
# 1305                      New York NK    Miss
# 1306                      New York NK      Mr
# 1307                      New York NK      Mr
# 1308                      New York NK      Mr
#
# [1309 rows x 12 columns]

# %%
B.isnull().sum()
# Out:
# pclass       0
# survived     0
# name         0
# sex          0
# age          0
# sibsp        0
# parch        0
# ticket       0
# fare         0
# embarked     0
# home.dest    0
# Title        0
# dtype: int64

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":       "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir":        "Royalty",

                   "Lady":        "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss":       "Miss",

                    "Ms":         "Mrs",

                    "Mr":         "Mr",

                    "Mrs":        "Mrs",

                    "Master":     "Master"

                    }

# %%
B["Title"].replace(Title_Dictionary,inplace=True)
B
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare embarked  \
# 0     female   29      0      0   24160  211.3375        S
# 1       male    0      1      2  113781  151.5500        S
# 2     female    2      1      2  113781  151.5500        S
# 3       male   30      1      2  113781  151.5500        S
# 4     female   25      1      2  113781  151.5500        S
# ...      ...  ...    ...    ...     ...       ...      ...
# 1304  female   14      1      0    2665   14.4542        C
# 1305  female   29      1      0    2665   14.4542        C
# 1306    male   26      0      0    2656    7.2250        C
# 1307    male   27      0      0    2670    7.2250        C
# 1308    male   29      0      0  315082    7.8750        S
#
#                             home.dest   Title
# 0                        St Louis, MO    Miss
# 1     Montreal, PQ / Chesterville, ON  Master
# 2     Montreal, PQ / Chesterville, ON    Miss
# 3     Montreal, PQ / Chesterville, ON      Mr
# 4     Montreal, PQ / Chesterville, ON     Mrs
# ...                               ...     ...
# 1304                      New York NK    Miss
# 1305                      New York NK    Miss
# 1306                      New York NK      Mr
# 1307                      New York NK      Mr
# 1308                      New York NK      Mr
#
# [1309 rows x 12 columns]

# %%
B["Title"].value_counts()
# Out:
# Mr         757
# Miss       263
# Mrs        199
# Master      61
# Officer     23
# Royalty      6
# Name: Title, dtype: int64

# %%
import seaborn as sns
sns.factorplot('sex',data=B,kind="count", hue="Title")
# Out:
# C:\Users\TERIAK-JB\anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
B.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#    age  sibsp  parch    ticket      fare embarked  \
# 0   29      0      0     24160  211.3375        S
# 1    0      1      2    113781  151.5500        S
# 2    2      1      2    113781  151.5500        S
# 3   30      1      2    113781  151.5500        S
# 4   25      1      2    113781  151.5500        S
# 5   48      0      0     19952   26.5500        S
# 6   63      1      0     13502   77.9583        S
# 7   39      0      0    112050    0.0000        S
# 8   53      2      0     11769   51.4792        S
# 9   71      0      0  PC 17609   49.5042        C
#
#                          home.dest   Title
# 0                     St Louis, MO    Miss
# 1  Montreal, PQ / Chesterville, ON  Master
# 2  Montreal, PQ / Chesterville, ON    Miss
# 3  Montreal, PQ / Chesterville, ON      Mr
# 4  Montreal, PQ / Chesterville, ON     Mrs
# 5                     New York, NY      Mr
# 6                       Hudson, NY    Miss
# 7                      Belfast, NI      Mr
# 8              Bayside, Queens, NY     Mrs
# 9              Montevideo, Uruguay      Mr

# %%
Family=pd.DataFrame()
Family=B["Family"]=B["parch"]+B["sibsp"]
Family
# Out:
# 0       0
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Length: 1309, dtype: int64

# %%
Family_Title=pd.DataFrame()
Family_Title=B[['Family','Title']].groupby(['Family'],as_index=True)
Family_Title

# %%
B.name.unique()
# Out:
# array(['Allen, Miss. Elisabeth Walton', 'Allison, Master. Hudson Trevor',
#        'Allison, Miss. Helen Loraine', ..., 'Zakarian, Mr. Mapriededer',
#        'Zakarian, Mr. Ortin', 'Zimmerman, Mr. Leo'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
B['name']=encoder.fit_transform(B['name'])
B
# Out:
#       pclass  survived  name     sex  age  sibsp  parch  ticket      fare  \
# 0          1         1    21  female   29      0      0   24160  211.3375
# 1          1         1    23    male    0      1      2  113781  151.5500
# 2          1         0    24  female    2      1      2  113781  151.5500
# 3          1         0    25    male   30      1      2  113781  151.5500
# 4          1         0    26  female   25      1      2  113781  151.5500
# ...      ...       ...   ...     ...  ...    ...    ...     ...       ...
# 1304       3         0  1291  female   14      1      0    2665   14.4542
# 1305       3         0  1292  female   29      1      0    2665   14.4542
# 1306       3         0  1293    male   26      0      0    2656    7.2250
# 1307       3         0  1294    male   27      0      0    2670    7.2250
# 1308       3         0  1295    male   29      0      0  315082    7.8750
#
#      embarked                        home.dest   Title  Family
# 0           S                     St Louis, MO    Miss       0
# 1           S  Montreal, PQ / Chesterville, ON  Master       3
# 2           S  Montreal, PQ / Chesterville, ON    Miss       3
# 3           S  Montreal, PQ / Chesterville, ON      Mr       3
# 4           S  Montreal, PQ / Chesterville, ON     Mrs       3
# ...       ...                              ...     ...     ...
# 1304        C                      New York NK    Miss       1
# 1305        C                      New York NK    Miss       1
# 1306        C                      New York NK      Mr       0
# 1307        C                      New York NK      Mr       0
# 1308        S                      New York NK      Mr       0
#
# [1309 rows x 13 columns]

# %%
encoder=LabelEncoder()
B['embarked']=encoder.fit_transform(B['embarked'])

# %%
Cleanup_nums={"female":1,"male":0
}
B.replace(Cleanup_nums,inplace=True)
B
# Out:
#       pclass  survived  name  sex  age  sibsp  parch  ticket      fare  \
# 0          1         1    21    1   29      0      0   24160  211.3375
# 1          1         1    23    0    0      1      2  113781  151.5500
# 2          1         0    24    1    2      1      2  113781  151.5500
# 3          1         0    25    0   30      1      2  113781  151.5500
# 4          1         0    26    1   25      1      2  113781  151.5500
# ...      ...       ...   ...  ...  ...    ...    ...     ...       ...
# 1304       3         0  1291    1   14      1      0    2665   14.4542
# 1305       3         0  1292    1   29      1      0    2665   14.4542
# 1306       3         0  1293    0   26      0      0    2656    7.2250
# 1307       3         0  1294    0   27      0      0    2670    7.2250
# 1308       3         0  1295    0   29      0      0  315082    7.8750
#
#       embarked                        home.dest   Title  Family
# 0            2                     St Louis, MO    Miss       0
# 1            2  Montreal, PQ / Chesterville, ON  Master       3
# 2            2  Montreal, PQ / Chesterville, ON    Miss       3
# 3            2  Montreal, PQ / Chesterville, ON      Mr       3
# 4            2  Montreal, PQ / Chesterville, ON     Mrs       3
# ...        ...                              ...     ...     ...
# 1304         0                      New York NK    Miss       1
# 1305         0                      New York NK    Miss       1
# 1306         0                      New York NK      Mr       0
# 1307         0                      New York NK      Mr       0
# 1308         2                      New York NK      Mr       0
#
# [1309 rows x 13 columns]

# %%
#import relevant libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

#features extraction
x=B[["age",'sex',"Family", "embarked"]]
y=B["survived"]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

logreg = LogisticRegression()   #build our logistic model
logreg.fit(x_train, y_train)  #fitting training data
y_pred  = logreg.predict(x_test)    #testing model’s performance
print("Accuracy={:.2f}".format(logreg.score(x_test, y_test)))
# Out:
# Accuracy=0.77

# %%
sns.regplot(x='embarked',y='survived',data=B,logistic=True)

# %%
confusion_matrix = pd.crosstab(y_test,y_pred,rownames=['actual'],colnames=['predicted'])
print (confusion_matrix)
# Out:
# predicted    0    1
# actual
# 0          246   40
# 1           65  108

# %%
fpr, tpr,_=roc_curve(logreg.predict(x),y,drop_intermediate=False)
import matplotlib.pyplot as plt
plt.figure(figsize=(7, 7))
plt.plot(fpr, tpr, color='red',
 lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='blue', lw=2, linestyle='--')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC curve')
plt.show()
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score

# %% [markdown]
# l'allure de la courbe se repproche de l'axe des ordonnées.les données sont correctes
